# %% [markdown]
# Select "Runtime" -> "Change runtime type"
# Change type to "GPU".

# %%
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:            12G        2.8G        3.5G        261M        6.3G         10G
# Swap:            0B          0B          0B

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/SSD_ADAS/ssd_keras/")
print("Working directory:", os.getcwd())
# Out:
# Working directory: /content/gdrive/My Drive/SSD_ADAS/ssd_keras

# %%
from keras import backend as K
from keras.models import load_model
from keras.optimizers import Adam
from scipy.misc import imread
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization
from data_generator.object_detection_2d_data_generator import DataGenerator
from eval_utils.average_precision_evaluator import Evaluator
# Out:
# Using TensorFlow backend.

# %%
img_height = 300
img_width = 300
n_classes = 80 # COCO classes
model_mode = 'training' # Do this even when evaluating.

# 1: Build the Keras model
K.clear_session() # Clear previous models from memory.
model = ssd_300(image_size=(img_height, img_width, 3),
                n_classes=n_classes,
                mode=model_mode,
                l2_regularization=0.0005,
                scales= [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05], # COCO
                aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5]],
                two_boxes_for_ar1=True,
                steps=[8, 16, 32, 64, 100, 300],
                offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                clip_boxes=False,
                variances=[0.1, 0.1, 0.2, 0.2],
                normalize_coords=True,
                subtract_mean=[123, 117, 104],
                swap_channels=[2, 1, 0],
                confidence_thresh=0.01,
                iou_threshold=0.45,
                top_k=200,
                nms_max_output_size=400)

# 2: Load the trained weights into the model.
weights_path = '../pretrained_weights/VGG_coco_SSD_300x300_iter_400000.h5'
model.load_weights(weights_path, by_name=True)

# 3: Compile the model so that Keras won't complain the next time you load it.
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
# Make datagen

images_dir = '../FLIR_ADAS/validation/PreviewData'
annotation_csv = '../validation.csv'
input_format = ["image_name", "class_id", "xmin", "xmax", "ymin", "ymax"] # order of columns in csv

dataset = DataGenerator(load_images_into_memory=True)
dataset.parse_csv(
    images_dir,
    annotation_csv,
    input_format,
    verbose=True
    )
# Out:
# Loading images into memory: 100%|██████████| 1360/1360 [00:08<00:00, 167.48it/s]

# %%
# Create Evaluator instance, caching predictions
evaluator = Evaluator(model=model,
                      n_classes=n_classes,
                      data_generator=dataset,
                      model_mode=model_mode)

# %%
# Evaluate the cached predictions
results = evaluator(img_height=img_height,
                    img_width=img_width,
                    batch_size=64,
                    data_generator_mode='resize',
                    matching_iou_threshold=0.5,
                    average_precision_mode='integrate',
                    return_precisions=True,
                    return_recalls=True,
                    return_average_precisions=True,
                    verbose=True)

mean_average_precision, average_precisions, precisions, recalls = results
# Out:
# Number of images in the evaluation dataset: 1360
#
# Producing predictions batch-wise: 100%|██████████| 22/22 [10:05<00:00, 21.71s/it]
# Matching predictions to ground truth, class 1/80.: 100%|██████████| 147778/147778 [00:18<00:00, 8195.78it/s]
# Matching predictions to ground truth, class 2/80.: 100%|██████████| 1707/1707 [00:00<00:00, 9861.84it/s]
# Matching predictions to ground truth, class 3/80.: 100%|██████████| 84515/84515 [00:10<00:00, 7899.91it/s]
# Matching predictions to ground truth, class 4/80.: 100%|██████████| 111/111 [00:00<00:00, 8122.97it/s]
# Matching predictions to ground truth, class 5/80.: 100%|██████████| 196/196 [00:00<00:00, 11153.40it/s]
# Matching predictions to ground truth, class 6/80.: 100%|██████████| 320/320 [00:00<00:00, 12694.14it/s]
# Matching predictions to ground truth, class 7/80.: 100%|██████████| 2222/2222 [00:00<00:00, 30395.99it/s]
# Matching predictions to ground truth, class 8/80.: 100%|██████████| 2323/2323 [00:00<00:00, 28584.33it/s]
# Matching predictions to ground truth, class 9/80.: 100%|██████████| 2439/2439 [00:00<00:00, 28710.61it/s]
# Matching predictions to ground truth, class 10/80.: 100%|██████████| 3969/3969 [00:00<00:00, 28641.66it/s]
# Matching predictions to ground truth, class 11/80.: 100%|██████████| 46/46 [00:00<00:00, 5390.99it/s]
# Matching predictions to ground truth, class 12/80.: 100%|██████████| 6/6 [00:00<00:00, 1358.63it/s]
# Matching predictions to ground truth, class 13/80.: 100%|██████████| 67/67 [00:00<00:00, 7435.92it/s]
# Matching predictions to ground truth, class 14/80.: 100%|██████████| 7653/7653 [00:00<00:00, 29841.55it/s]
# Matching predictions to ground truth, class 15/80.: 100%|██████████| 3081/3081 [00:00<00:00, 26520.46it/s]
# Matching predictions to ground truth, class 16/80.: 100%|██████████| 17/17 [00:00<00:00, 3128.16it/s]
# Matching predictions to ground truth, class 17/80.: 100%|██████████| 131/131 [00:00<00:00, 9134.73it/s]
# Matching predictions to ground truth, class 18/80.: 100%|██████████| 42/42 [00:00<00:00, 3787.34it/s]
# Matching predictions to ground truth, class 19/80.: 100%|██████████| 72/72 [00:00<00:00, 5878.95it/s]
# Matching predictions to ground truth, class 20/80.: 100%|██████████| 11/11 [00:00<00:00, 1613.02it/s]
# Matching predictions to ground truth, class 21/80.: 100%|██████████| 13/13 [00:00<00:00, 1787.56it/s]
# Matching predictions to ground truth, class 22/80.: 100%|██████████| 1/1 [00:00<00:00, 189.46it/s]
# Matching predictions to ground truth, class 23/80.: 100%|██████████| 15/15 [00:00<00:00, 1795.87it/s]
# Matching predictions to ground truth, class 24/80.: 100%|██████████| 84/84 [00:00<00:00, 6656.49it/s]
# Matching predictions to ground truth, class 25/80.: 100%|██████████| 20/20 [00:00<00:00, 3508.56it/s]
# Matching predictions to ground truth, class 26/80.: 100%|██████████| 2548/2548 [00:00<00:00, 29844.19it/s]
# Matching predictions to ground truth, class 27/80.: 100%|██████████| 459/459 [00:00<00:00, 17721.43it/s]
# Matching predictions to ground truth, class 28/80.: 100%|██████████| 58/58 [00:00<00:00, 5510.07it/s]
# Matching predictions to ground truth, class 29/80.: 100%|██████████| 50/50 [00:00<00:00, 4816.72it/s]
# Matching predictions to ground truth, class 30/80.: 100%|██████████| 5/5 [00:00<00:00, 1069.98it/s]
# Matching predictions to ground truth, class 31/80.: 100%|██████████| 67/67 [00:00<00:00, 5638.07it/s]
# No predictions for class 32/80
# Matching predictions to ground truth, class 33/80.: 100%|██████████| 1075/1075 [00:00<00:00, 24468.20it/s]
# No predictions for class 34/80
# Matching predictions to ground truth, class 35/80.: 100%|██████████| 132/132 [00:00<00:00, 11146.08it/s]
# Matching predictions to ground truth, class 36/80.: 100%|██████████| 4/4 [00:00<00:00, 775.47it/s]
# Matching predictions to ground truth, class 37/80.: 100%|██████████| 125/125 [00:00<00:00, 8702.45it/s]
# Matching predictions to ground truth, class 38/80.: 100%|██████████| 22/22 [00:00<00:00, 3521.26it/s]
# Matching predictions to ground truth, class 39/80.: 100%|██████████| 44/44 [00:00<00:00, 5325.33it/s]
# Matching predictions to ground truth, class 40/80.: 100%|██████████| 796/796 [00:00<00:00, 22788.13it/s]
# Matching predictions to ground truth, class 41/80.: 100%|██████████| 1325/1325 [00:00<00:00, 23570.20it/s]
# Matching predictions to ground truth, class 42/80.: 100%|██████████| 695/695 [00:00<00:00, 22204.76it/s]
# No predictions for class 43/80
# Matching predictions to ground truth, class 44/80.: 100%|██████████| 2/2 [00:00<00:00, 262.88it/s]
# Matching predictions to ground truth, class 45/80.: 100%|██████████| 1/1 [00:00<00:00, 188.51it/s]
# Matching predictions to ground truth, class 46/80.: 100%|██████████| 19/19 [00:00<00:00, 3143.29it/s]
# Matching predictions to ground truth, class 47/80.: 100%|██████████| 43/43 [00:00<00:00, 4456.40it/s]
# No predictions for class 48/80
# No predictions for class 49/80
# No predictions for class 50/80
# No predictions for class 51/80
# No predictions for class 52/80
# No predictions for class 53/80
# No predictions for class 54/80
# No predictions for class 55/80
# No predictions for class 56/80
# Matching predictions to ground truth, class 57/80.: 100%|██████████| 875/875 [00:00<00:00, 24306.83it/s]
# Matching predictions to ground truth, class 58/80.: 100%|██████████| 2/2 [00:00<00:00, 548.35it/s]
# Matching predictions to ground truth, class 59/80.: 100%|██████████| 5764/5764 [00:00<00:00, 29908.72it/s]
# Matching predictions to ground truth, class 60/80.: 100%|██████████| 8/8 [00:00<00:00, 895.81it/s]
# Matching predictions to ground truth, class 61/80.: 100%|██████████| 80/80 [00:00<00:00, 7836.89it/s]
# Matching predictions to ground truth, class 62/80.: 100%|██████████| 4/4 [00:00<00:00, 755.12it/s]
# Matching predictions to ground truth, class 63/80.: 100%|██████████| 12/12 [00:00<00:00, 1885.50it/s]
# Matching predictions to ground truth, class 64/80.: 100%|██████████| 4/4 [00:00<00:00, 742.03it/s]
# Matching predictions to ground truth, class 65/80.: 100%|██████████| 1/1 [00:00<00:00, 209.20it/s]
# Matching predictions to ground truth, class 66/80.: 100%|██████████| 12/12 [00:00<00:00, 1748.48it/s]
# Matching predictions to ground truth, class 67/80.: 100%|██████████| 7/7 [00:00<00:00, 1268.09it/s]
# Matching predictions to ground truth, class 68/80.: 100%|██████████| 4/4 [00:00<00:00, 584.23it/s]
# Matching predictions to ground truth, class 69/80.: 100%|██████████| 2/2 [00:00<00:00, 332.59it/s]
# Matching predictions to ground truth, class 70/80.: 100%|██████████| 3/3 [00:00<00:00, 517.30it/s]
# No predictions for class 71/80
# Matching predictions to ground truth, class 72/80.: 100%|██████████| 55/55 [00:00<00:00, 4864.14it/s]
# Matching predictions to ground truth, class 73/80.: 100%|██████████| 3/3 [00:00<00:00, 359.33it/s]
# Matching predictions to ground truth, class 74/80.: 100%|██████████| 553/553 [00:00<00:00, 21029.13it/s]
# Matching predictions to ground truth, class 75/80.: 100%|██████████| 147/147 [00:00<00:00, 9480.91it/s]
# Matching predictions to ground truth, class 76/80.: 100%|██████████| 82/82 [00:00<00:00, 5809.09it/s]
# No predictions for class 77/80
# Matching predictions to ground truth, class 78/80.: 100%|██████████| 72/72 [00:00<00:00, 7266.53it/s]
# No predictions for class 79/80
# Matching predictions to ground truth, class 80/80.: 100%|██████████| 1/1 [00:00<00:00, 191.24it/s]
# Computing precisions and recalls, class 1/80
# Computing precisions and recalls, class 2/80
# Computing precisions and recalls, class 3/80
# Computing precisions and recalls, class 4/80
# Computing precisions and recalls, class 5/80
# Computing precisions and recalls, class 6/80
# Computing precisions and recalls, class 7/80
# Computing precisions and recalls, class 8/80
# Computing precisions and recalls, class 9/80
# Computing precisions and recalls, class 10/80
# Computing precisions and recalls, class 11/80
# Computing precisions and recalls, class 12/80
# Computing precisions and recalls, class 13/80
# Computing precisions and recalls, class 14/80
# Computing precisions and recalls, class 15/80
# Computing precisions and recalls, class 16/80
# Computing precisions and recalls, class 17/80
# Computing precisions and recalls, class 18/80
# Computing precisions and recalls, class 19/80
# Computing precisions and recalls, class 20/80
# Computing precisions and recalls, class 21/80
# Computing precisions and recalls, class 22/80
# Computing precisions and recalls, class 23/80
# Computing precisions and recalls, class 24/80
# Computing precisions and recalls, class 25/80
# Computing precisions and recalls, class 26/80
# Computing precisions and recalls, class 27/80
# Computing precisions and recalls, class 28/80
# Computing precisions and recalls, class 29/80
# Computing precisions and recalls, class 30/80
# Computing precisions and recalls, class 31/80
# Computing precisions and recalls, class 32/80
# Computing precisions and recalls, class 33/80
# Computing precisions and recalls, class 34/80
# Computing precisions and recalls, class 35/80
# Computing precisions and recalls, class 36/80
# Computing precisions and recalls, class 37/80
# Computing precisions and recalls, class 38/80
# Computing precisions and recalls, class 39/80
# Computing precisions and recalls, class 40/80
# Computing precisions and recalls, class 41/80
# Computing precisions and recalls, class 42/80
# Computing precisions and recalls, class 43/80
# Computing precisions and recalls, class 44/80
# Computing precisions and recalls, class 45/80
# Computing precisions and recalls, class 46/80
# Computing precisions and recalls, class 47/80
# Computing precisions and recalls, class 48/80
# Computing precisions and recalls, class 49/80
# Computing precisions and recalls, class 50/80
# Computing precisions and recalls, class 51/80
# Computing precisions and recalls, class 52/80
# Computing precisions and recalls, class 53/80
# Computing precisions and recalls, class 54/80
# Computing precisions and recalls, class 55/80
# Computing precisions and recalls, class 56/80
# Computing precisions and recalls, class 57/80
# Computing precisions and recalls, class 58/80
# Computing precisions and recalls, class 59/80
# Computing precisions and recalls, class 60/80
# Computing precisions and recalls, class 61/80
# Computing precisions and recalls, class 62/80
# Computing precisions and recalls, class 63/80
# Computing precisions and recalls, class 64/80
# Computing precisions and recalls, class 65/80
# Computing precisions and recalls, class 66/80
# Computing precisions and recalls, class 67/80
# Computing precisions and recalls, class 68/80
# Computing precisions and recalls, class 69/80
# Computing precisions and recalls, class 70/80
# Computing precisions and recalls, class 71/80
# Computing precisions and recalls, class 72/80
# Computing precisions and recalls, class 73/80
# Computing precisions and recalls, class 74/80
# Computing precisions and recalls, class 75/80
# Computing precisions and recalls, class 76/80
# Computing precisions and recalls, class 77/80
# Computing precisions and recalls, class 78/80
# Computing precisions and recalls, class 79/80
# Computing precisions and recalls, class 80/80
# Computing average precision, class 1/80
# Computing average precision, class 2/80
# Computing average precision, class 3/80
# Computing average precision, class 4/80
# Computing average precision, class 5/80
# Computing average precision, class 6/80
# Computing average precision, class 7/80
# /content/gdrive/My Drive/SSD_ADAS/ssd_keras/eval_utils/average_precision_evaluator.py:776: RuntimeWarning: invalid value encountered in true_divide
#   cumulative_recall = tp / self.num_gt_per_class[class_id] # 1D array with shape `(num_predictions,)`
# Computing average precision, class 8/80
# Computing average precision, class 9/80
# Computing average precision, class 10/80
# Computing average precision, class 11/80
# Computing average precision, class 12/80
# Computing average precision, class 13/80
# Computing average precision, class 14/80
# Computing average precision, class 15/80
# Computing average precision, class 16/80
# Computing average precision, class 17/80
# Computing average precision, class 18/80
# Computing average precision, class 19/80
# Computing average precision, class 20/80
# Computing average precision, class 21/80
# Computing average precision, class 22/80
# Computing average precision, class 23/80
# Computing average precision, class 24/80
# Computing average precision, class 25/80
# Computing average precision, class 26/80
# Computing average precision, class 27/80
# Computing average precision, class 28/80
# Computing average precision, class 29/80
# Computing average precision, class 30/80
# Computing average precision, class 31/80
# Computing average precision, class 32/80
# Computing average precision, class 33/80
# Computing average precision, class 34/80
# Computing average precision, class 35/80
# Computing average precision, class 36/80
# Computing average precision, class 37/80
# Computing average precision, class 38/80
# Computing average precision, class 39/80
# Computing average precision, class 40/80
# Computing average precision, class 41/80
# Computing average precision, class 42/80
# Computing average precision, class 43/80
# Computing average precision, class 44/80
# Computing average precision, class 45/80
# Computing average precision, class 46/80
# Computing average precision, class 47/80
# Computing average precision, class 48/80
# Computing average precision, class 49/80
# Computing average precision, class 50/80
# Computing average precision, class 51/80
# Computing average precision, class 52/80
# Computing average precision, class 53/80
# Computing average precision, class 54/80
# Computing average precision, class 55/80
# Computing average precision, class 56/80
# Computing average precision, class 57/80
# Computing average precision, class 58/80
# Computing average precision, class 59/80
# Computing average precision, class 60/80
# Computing average precision, class 61/80
# Computing average precision, class 62/80
# Computing average precision, class 63/80
# Computing average precision, class 64/80
# Computing average precision, class 65/80
# Computing average precision, class 66/80
# Computing average precision, class 67/80
# Computing average precision, class 68/80
# Computing average precision, class 69/80
# Computing average precision, class 70/80
# Computing average precision, class 71/80
# Computing average precision, class 72/80
# Computing average precision, class 73/80
# Computing average precision, class 74/80
# Computing average precision, class 75/80
# Computing average precision, class 76/80
# Computing average precision, class 77/80
# Computing average precision, class 78/80
# Computing average precision, class 79/80
# Computing average precision, class 80/80

# %%
classes_of_interest = {1:"person", 2:"bicycle", 3:"car", 17:"dog"}

for i in classes_of_interest.keys():
    print("{:<14}{:<6}{}".format(classes_of_interest[i], 'AP', round(average_precisions[i], 3)))
print()
print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))
# Out:
# person        AP    0.112
# bicycle       AP    0.022
# car           AP    0.252
# dog           AP    0.0
#
#               mAP   nan

# %%
def plot_PR(class_id):
  plt.figure()
  plt.plot(recalls[class_id], precisions[class_id])
  plt.xlabel('recall')
  plt.ylabel('precision')
  plt.xticks(np.linspace(0,1,11))
  plt.yticks(np.linspace(0,1,11))
  plt.title(
      "Class id: {} ({}), AP: {:.3f}".format(class_id, classes_of_interest[class_id], average_precisions[class_id])
  )
  
def plot_PRs(class_ids):
  plt.figure()
  
  for class_id in class_ids:
    plt.plot(
        recalls[class_id],
        precisions[class_id],
        label = "{}, AP: {:.3f}".format(classes_of_interest[class_id], average_precisions[class_id]))
    
  #plt.xlim((0,1))
  #plt.ylim((0,1))
  plt.xticks(np.linspace(0,1,11))
  plt.yticks(np.linspace(0,1,11))
  plt.legend()
  return
    
plot_PRs(classes_of_interest.keys())

# %%
for class_id in classes_of_interest.keys():
  plt.figure()
  plot_PR(class_id)

# %%
# !df -h /tmp
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         359G  8.8G  332G   3% /
