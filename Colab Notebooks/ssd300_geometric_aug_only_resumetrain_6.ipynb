# %%
from google.colab import drive
from os import chdir, getcwd

drive.mount('/content/gdrive')
chdir("/content/gdrive/My Drive/SSD_ADAS/ssd_keras/")
print("Working directory:", getcwd())
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Working directory: /content/gdrive/My Drive/SSD_ADAS/ssd_keras

# %%
from data_generator.object_detection_2d_data_generator import DataGenerator

input_format = ["image_name", "class_id", "xmin", "xmax", "ymin", "ymax"] # order of columns in the annotation csv

# Load validation data
validation_image_dir = "../FLIR_ADAS/validation/PreviewData"
validation_annotation_csv = "../validation.csv"

validation_dataset = DataGenerator()
validation_dataset.parse_csv(
    validation_image_dir,
    validation_annotation_csv,
    input_format
)
print("{} images in validation set.".format(validation_dataset.get_dataset_size()))

# Load training data
training_image_dir = "../FLIR_ADAS/training/PreviewData"
training_annotation_csv = "../training.csv"

training_dataset = DataGenerator()
training_dataset.parse_csv(
    training_image_dir,
    training_annotation_csv,
    input_format
)
print("{} images in training set.".format(training_dataset.get_dataset_size()))
# Out:
# 1360 images in validation set.
# 7860 images in training set.

# %%
! ls *.h5
# Out:
# ssd300_geometric_aug_only_epoch-30_loss-4.4751_val_loss-3.8531.h5
# ssd300_geometric_aug_only_finetuning_epoch-62_loss-3.7001_val_loss-3.1833.h5
# ssd300_geometric_aug_only_finetuning_epoch-63_loss-3.6594_val_loss-3.1816.h5
# ssd300_geometric_aug_only_finetuning_epoch-63_loss-3.9057_val_loss-3.5233.h5
# ssd300_pascal_07+12_epoch-05_loss-4.2953_val_loss-3.7685.h5
# ssd300_test4_epoch-03_loss-3.1129_val_loss-3.8558.h5
# ssd300_untrained_coco.h5

# %%
from keras import backend as K
from keras.models import load_model

from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_L2Normalization import L2Normalization
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_loss_function.keras_ssd_loss import SSDLoss

def load_ssd(h5_filename):
  #Clear previously loaded models
  K.clear_session()
  
  #Fill in the custom objects so that Keras can load the model
  ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
  
  custom_objects = {
      'AnchorBoxes': AnchorBoxes,
      'L2Normalization': L2Normalization,
      'DecodeDetections': DecodeDetections,
      'compute_loss': ssd_loss.compute_loss}
  
  #Load the model
  model = load_model(h5_filename, custom_objects)
  print("Model loaded:", h5_filename)
  
  return model
  
model = load_ssd("ssd300_geometric_aug_only_finetuning_epoch-63_loss-3.6594_val_loss-3.1816.h5")
# Out:
# Using TensorFlow backend.
# Model loaded: ssd300_geometric_aug_only_finetuning_epoch-63_loss-3.6594_val_loss-3.1816.h5

# %%
from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder

img_height = 300
img_width = 300
n_classes = 80 # COCO classes

scales = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                         [1.0, 2.0, 0.5],
                         [1.0, 2.0, 0.5]]

two_boxes_for_ar1=True
steps=[8, 16, 32, 64, 100, 300]
offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
clip_boxes=False
variances=[0.1, 0.1, 0.2, 0.2]
normalize_coords=True

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios_per_layer,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# %%
from data_generator.object_detection_2d_geometric_ops import Resize, ResizeRandomInterp
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDExpand, SSDRandomCrop
from data_generator.object_detection_2d_geometric_ops import RandomFlip
from data_generator.object_detection_2d_image_boxes_validation_utils import BoxFilter

import cv2

mean_color = [128, 128, 128]

# For validation images
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# SSD augmentation chain without photometric ops
expand = SSDExpand(background=mean_color)
random_crop = SSDRandomCrop()
random_flip = RandomFlip(dim='horizontal', prob=0.5)
box_filter = BoxFilter(check_overlap=False, check_min_area=False, check_degenerate=True)
resize_random_interp = ResizeRandomInterp(
    height=img_height,
    width=img_width,
    interpolation_modes=[cv2.INTER_NEAREST, cv2.INTER_LINEAR, cv2.INTER_CUBIC, cv2.INTER_AREA, cv2.INTER_LANCZOS4],
    box_filter=box_filter)

# %%
# Create training and validation generators
batch_size = 8

train_generator = training_dataset.generate(
    batch_size=batch_size,
    shuffle=True,
    transformations=[convert_to_3_channels, expand, random_crop, random_flip, resize_random_interp],
    label_encoder=ssd_input_encoder,
    returns={'processed_images', 'encoded_labels'},
    keep_images_without_gt=False)

val_generator = validation_dataset.generate(
    batch_size=batch_size,
    shuffle=False,
    transformations=[convert_to_3_channels, resize],
    label_encoder=ssd_input_encoder,
    returns={'processed_images', 'encoded_labels'},
    keep_images_without_gt=False)

# %%
# Define model callbacks.

from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, TerminateOnNaN

model_checkpoint = ModelCheckpoint(
    filepath='ssd300_geometric_aug_only_finetuning_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
    monitor='val_loss',
    verbose=1,
    save_best_only=True)

csv_logger = CSVLogger(
    filename='ssd300_ADAS_geometric_aug_only_finetune_training_log.csv',
    append=True)

reduce_lr_on_plateau = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_delta=0.0001)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             reduce_lr_on_plateau,
             terminate_on_nan]

# %%
from keras.optimizers import Adam

# Set learning rate
lr = 0.001 / 10

adam = Adam(lr=lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
# Train the model

from math import ceil

initial_epoch   = 63
final_epoch     = 200
steps_per_epoch = 1000

history = model.fit_generator(
    generator=train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=final_epoch,
    callbacks=callbacks,
    validation_data=val_generator,
    validation_steps=ceil(validation_dataset.get_dataset_size()/batch_size),
    initial_epoch=initial_epoch)
# Out:
# Epoch 64/200
# 1000/1000 [==============================] - 5534s 6s/step - loss: 3.7124 - val_loss: 3.2327
#
# Epoch 00064: val_loss improved from inf to 3.23266, saving model to ssd300_geometric_aug_only_finetuning_epoch-64_loss-3.7125_val_loss-3.2327.h5
# Epoch 65/200
# 1000/1000 [==============================] - 865s 865ms/step - loss: 3.6883 - val_loss: 3.2658
#
# Epoch 00065: val_loss did not improve from 3.23266
# Epoch 66/200
# 1000/1000 [==============================] - 865s 865ms/step - loss: 3.7569 - val_loss: 3.2152
#
# Epoch 00066: val_loss improved from 3.23266 to 3.21521, saving model to ssd300_geometric_aug_only_finetuning_epoch-66_loss-3.7574_val_loss-3.2152.h5
# Epoch 67/200
# 1000/1000 [==============================] - 865s 865ms/step - loss: 3.6845 - val_loss: 3.2273
#
# Epoch 00067: val_loss did not improve from 3.21521
# Epoch 68/200
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.7096 - val_loss: 3.2512
#
# Epoch 00068: val_loss did not improve from 3.21521
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 69/200
# 1000/1000 [==============================] - 868s 868ms/step - loss: 3.6895 - val_loss: 3.1755
#
# Epoch 00069: val_loss improved from 3.21521 to 3.17554, saving model to ssd300_geometric_aug_only_finetuning_epoch-69_loss-3.6896_val_loss-3.1755.h5
# Epoch 70/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6696 - val_loss: 3.2084
#
# Epoch 00070: val_loss did not improve from 3.17554
# Epoch 71/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6472 - val_loss: 3.2038
#
# Epoch 00071: val_loss did not improve from 3.17554
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 72/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6415 - val_loss: 3.1914
#
# Epoch 00072: val_loss did not improve from 3.17554
# Epoch 73/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6465 - val_loss: 3.1624
#
# Epoch 00073: val_loss improved from 3.17554 to 3.16244, saving model to ssd300_geometric_aug_only_finetuning_epoch-73_loss-3.6466_val_loss-3.1624.h5
# Epoch 74/200
# 1000/1000 [==============================] - 868s 868ms/step - loss: 3.6385 - val_loss: 3.1826
#
# Epoch 00074: val_loss did not improve from 3.16244
# Epoch 75/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.6713 - val_loss: 3.1580
#
# Epoch 00075: val_loss improved from 3.16244 to 3.15802, saving model to ssd300_geometric_aug_only_finetuning_epoch-75_loss-3.6714_val_loss-3.1580.h5
# Epoch 76/200
# 1000/1000 [==============================] - 872s 872ms/step - loss: 3.6250 - val_loss: 3.1754
#
# Epoch 00076: val_loss did not improve from 3.15802
# Epoch 77/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6510 - val_loss: 3.2008
#
# Epoch 00077: val_loss did not improve from 3.15802
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 78/200
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.6339 - val_loss: 3.1577
#
# Epoch 00078: val_loss improved from 3.15802 to 3.15773, saving model to ssd300_geometric_aug_only_finetuning_epoch-78_loss-3.6339_val_loss-3.1577.h5
# Epoch 79/200
# 1000/1000 [==============================] - 868s 868ms/step - loss: 3.6375 - val_loss: 3.1954
#
# Epoch 00079: val_loss did not improve from 3.15773
# Epoch 80/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6225 - val_loss: 3.1743
#
# Epoch 00080: val_loss did not improve from 3.15773
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 81/200
# 1000/1000 [==============================] - 871s 871ms/step - loss: 3.6242 - val_loss: 3.1645
#
# Epoch 00081: val_loss did not improve from 3.15773
# Epoch 82/200
# 1000/1000 [==============================] - 870s 870ms/step - loss: 3.6184 - val_loss: 3.1497
#
# Epoch 00082: val_loss improved from 3.15773 to 3.14971, saving model to ssd300_geometric_aug_only_finetuning_epoch-82_loss-3.6181_val_loss-3.1497.h5
# Epoch 83/200
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.6245 - val_loss: 3.1582
#
# Epoch 00083: val_loss did not improve from 3.14971
# Epoch 84/200
# 1000/1000 [==============================] - 868s 868ms/step - loss: 3.6339 - val_loss: 3.1668
#
# Epoch 00084: val_loss did not improve from 3.14971
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 85/200
# 1000/1000 [==============================] - 868s 868ms/step - loss: 3.6152 - val_loss: 3.1505
#
# Epoch 00085: val_loss did not improve from 3.14971
# Epoch 86/200
# 1000/1000 [==============================] - 868s 868ms/step - loss: 3.6152 - val_loss: 3.1571
#
# Epoch 00086: val_loss did not improve from 3.14971
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 87/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.6170 - val_loss: 3.1573
#
# Epoch 00087: val_loss did not improve from 3.14971
# Epoch 88/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.6138 - val_loss: 3.1547
#
# Epoch 00088: val_loss did not improve from 3.14971
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 89/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.5974 - val_loss: 3.1509
#
# Epoch 00089: val_loss did not improve from 3.14971
# Epoch 90/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.6266 - val_loss: 3.1521
#
# Epoch 00090: val_loss did not improve from 3.14971
#
# Epoch 00090: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 91/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.6135 - val_loss: 3.1557
#
# Epoch 00091: val_loss did not improve from 3.14971
# Epoch 92/200
# 1000/1000 [==============================] - 869s 869ms/step - loss: 3.5861 - val_loss: 3.1570
#
# Epoch 00092: val_loss did not improve from 3.14971
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 93/200
# 1000/1000 [==============================] - 866s 866ms/step - loss: 3.6134 - val_loss: 3.1574
#
# Epoch 00093: val_loss did not improve from 3.14971
# Epoch 94/200
# 1000/1000 [==============================] - 866s 866ms/step - loss: 3.5742 - val_loss: 3.1560
#
# Epoch 00094: val_loss did not improve from 3.14971
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 95/200
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.5909 - val_loss: 3.1558
#
# Epoch 00095: val_loss did not improve from 3.14971
# Epoch 96/200
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.6415 - val_loss: 3.1557
#
# Epoch 00096: val_loss did not improve from 3.14971
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 97/200
# 1000/1000 [==============================] - 867s 867ms/step - loss: 3.6292 - val_loss: 3.1554
#
# Epoch 00097: val_loss did not improve from 3.14971
# Epoch 98/200
#  156/1000 [===>..........................] - ETA: 11:28 - loss: 3.5939
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9daca7f39a20> in <module>()
#      13     validation_data=val_generator,
#      14     validation_steps=ceil(validation_dataset.get_dataset_size()/batch_size),
# ---> 15     initial_epoch=initial_epoch)
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
